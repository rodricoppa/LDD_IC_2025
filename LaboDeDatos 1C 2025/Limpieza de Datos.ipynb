# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# Ejercicio 1
subconjunto = penguins[(penguins["island"] == "Biscoe") & (penguins["bill_length_mm"] >= 48)]
subconjunto
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 221  Gentoo  Biscoe            50.0           16.3              230.0
# 222  Gentoo  Biscoe            48.7           14.1              210.0
# 223  Gentoo  Biscoe            50.0           15.2              218.0
# 231  Gentoo  Biscoe            49.0           16.1              216.0
# 233  Gentoo  Biscoe            48.4           14.6              213.0
# 235  Gentoo  Biscoe            49.3           15.7              217.0
# 237  Gentoo  Biscoe            49.2           15.2              221.0
# 239  Gentoo  Biscoe            48.7           15.1              222.0
# 240  Gentoo  Biscoe            50.2           14.3              218.0
# 248  Gentoo  Biscoe            48.2           14.3              210.0
# 249  Gentoo  Biscoe            50.0           15.3              220.0
# 253  Gentoo  Biscoe            59.6           17.0              230.0
# ...

# %%
# Ejercicio 2
adelie_machos_no_biscoe = penguins[
    (penguins["species"] == 'Adelie') &
    (penguins['sex'] == 'Male') &
    (penguins['island'] != 'Biscoe')
]
adelie_machos_no_biscoe
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 13   Adelie  Torgersen            38.6           21.2              191.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# 17   Adelie  Torgersen            42.5           20.7              197.0
# 19   Adelie  Torgersen            46.0           21.5              194.0
# 31   Adelie      Dream            37.2           18.1              178.0
# 33   Adelie      Dream            40.9           18.9              184.0
# 35   Adelie      Dream            39.2           21.1              196.0
# 36   Adelie      Dream            38.8           20.0              190.0
# 39   Adelie      Dream            39.8           19.1              184.0
# ...

# %%
# Ejercicio 3
penguins.columns
penguins.drop(columns = [col for col in ["year", "sex", "body_mass_g"] if col in penguins.columns])
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
# [344 rows x 5 columns]

# %%
# Ejercicio 4
# a)
penguins[penguins["island"] != "Biscoe"]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 215  Chinstrap      Dream            55.8           19.8              207.0
# 216  Chinstrap      Dream            43.5           18.1              202.0
# 217  Chinstrap      Dream            49.6           18.2              193.0
# 218  Chinstrap      Dream            50.8           19.0              210.0
# 219  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# ...

# %%
cols = penguins.columns
i, j = cols.get_loc('species'), cols.get_loc('body_mass_g')
subset = penguins.loc[:, cols[i:j+1]]
subset
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g
# 0         3750.0
# 1         3800.0
# 2         3250.0
# 3            NaN
# ...

# %%
resultado = (
    penguins[penguins["island"] != "Biscoe"]
    .loc[:, lambda df : df.columns[df.columns.get_loc("species") : df.columns.get_loc("body_mass_g") + 1]]
    .rename(columns ={"species" : "especie_pinguino"})
    .groupby("especie_pinguino")
    .mean(numeric_only = True)
    .filter(like = "length")
    .add_suffix("_mean")
)
resultado
# Out:
#                   bill_length_mm_mean  flipper_length_mm_mean
# especie_pinguino
# Adelie                      38.715888              190.429907
# Chinstrap                   48.833824              195.823529

# %%
# Ejercicio 5
(
    penguins.rename(columns={
        'species': 'especies',
        'flipper_length_mm': 'aleta_mm',
        'body_mass_g': 'peso_g'
    })
    .rename(index={0: 'cero'})
)
# Out:
#      especies     island  bill_length_mm  bill_depth_mm  aleta_mm  peso_g  \
# cero   Adelie  Torgersen            39.1           18.7     181.0  3750.0
# 1      Adelie  Torgersen            39.5           17.4     186.0  3800.0
# 2      Adelie  Torgersen            40.3           18.0     195.0  3250.0
# 3      Adelie  Torgersen             NaN            NaN       NaN     NaN
# 4      Adelie  Torgersen            36.7           19.3     193.0  3450.0
# ...       ...        ...             ...            ...       ...     ...
# 339    Gentoo     Biscoe             NaN            NaN       NaN     NaN
# 340    Gentoo     Biscoe            46.8           14.3     215.0  4850.0
# 341    Gentoo     Biscoe            50.4           15.7     222.0  5750.0
# 342    Gentoo     Biscoe            45.2           14.8     212.0  5200.0
# 343    Gentoo     Biscoe            49.9           16.1     213.0  5400.0
#
#          sex
# cero    Male
# 1     Female
# 2     Female
# 3        NaN
# ...

# %%
penguins.rename(columns=str.upper)
# Out:
#     SPECIES     ISLAND  BILL_LENGTH_MM  BILL_DEPTH_MM  FLIPPER_LENGTH_MM  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      BODY_MASS_G     SEX
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.rename(index=np.sqrt)
# Out:
#           species     island  bill_length_mm  bill_depth_mm  \
# 0.000000   Adelie  Torgersen            39.1           18.7
# 1.000000   Adelie  Torgersen            39.5           17.4
# 1.414214   Adelie  Torgersen            40.3           18.0
# 1.732051   Adelie  Torgersen             NaN            NaN
# 2.000000   Adelie  Torgersen            36.7           19.3
# ...           ...        ...             ...            ...
# 18.411953  Gentoo     Biscoe             NaN            NaN
# 18.439089  Gentoo     Biscoe            46.8           14.3
# 18.466185  Gentoo     Biscoe            50.4           15.7
# 18.493242  Gentoo     Biscoe            45.2           14.8
# 18.520259  Gentoo     Biscoe            49.9           16.1
#
#            flipper_length_mm  body_mass_g     sex
# 0.000000               181.0       3750.0    Male
# 1.000000               186.0       3800.0  Female
# 1.414214               195.0       3250.0  Female
# ...

# %%
def suma_uno(x):
    return x + 1

penguins.rename(index=suma_uno)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 1    Adelie  Torgersen            39.1           18.7              181.0
# 2    Adelie  Torgersen            39.5           17.4              186.0
# 3    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen             NaN            NaN                NaN
# 5    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 340  Gentoo     Biscoe             NaN            NaN                NaN
# 341  Gentoo     Biscoe            46.8           14.3              215.0
# 342  Gentoo     Biscoe            50.4           15.7              222.0
# 343  Gentoo     Biscoe            45.2           14.8              212.0
# 344  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 1         3750.0    Male
# 2         3800.0  Female
# ...

# %%
penguins.rename(index=lambda x: x * 2)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 2    Adelie  Torgersen            39.5           17.4              186.0
# 4    Adelie  Torgersen            40.3           18.0              195.0
# 6    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 678  Gentoo     Biscoe             NaN            NaN                NaN
# 680  Gentoo     Biscoe            46.8           14.3              215.0
# 682  Gentoo     Biscoe            50.4           15.7              222.0
# 684  Gentoo     Biscoe            45.2           14.8              212.0
# 686  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 2         3800.0  Female
# ...

# %%
penguins.rename(columns=lambda x: x.upper())
# Out:
#     SPECIES     ISLAND  BILL_LENGTH_MM  BILL_DEPTH_MM  FLIPPER_LENGTH_MM  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      BODY_MASS_G     SEX
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# Ejercicio 6
df = pd.read_csv(r"C:\Users\Usuario\Downloads\macro_full_columns.csv")
df
# Out:
#     Unnamed: 0  Anio  FBKF.Construcciones.Priv_Publ  \
# 0            1  1950                    20353627362
# 1            2  1951                    21739314091
# 2            3  1952                    19685428171
# 3            4  1953                    20237375978
# 4            5  1954                    19372130307
# ..         ...   ...                            ...
# 61          62  2011                    66813943052
# 62          63  2012                    64700327691
# 63          64  2013                    64634666531
# 64          65  2014                    63301703123
# 65          66  2015                    64462175043
#
#     FBKF.Equi_Dur_Prod.Mat_Transp.Nac  FBKF.Equi_Dur_Prod.Mat_Transp.Import  \
# 0                        6.685869e+08                          5.844002e+08
# 1                        8.427402e+08                          2.532758e+09
# 2                        1.119084e+09                          1.484422e+09
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                              0
# Anio                                    0
# FBKF.Construcciones.Priv_Publ           0
# FBKF.Equi_Dur_Prod.Mat_Transp.Nac       0
# FBKF.Equi_Dur_Prod.Mat_Transp.Import    0
#                                        ..
# Vol_Cons_Hogares_per_Cap__vari_Porc     1
# Vol_FBKF_perCap__variPorc               1
# Vol_PIB_encaden_Fisher_2004             0
# IPI_volumen                             0
# IPI__variPorc                           1
# Length: 85, dtype: int64

# %%
df.columns[df.isna().any()]
# Out:
# Index(['EXPO_OTAGRIC_2004', 'EXPO_PESCA_2004', 'EXPO_ALIMENT_2004',
#        'EXPO_TEXTIL_2004', 'EXPO_CUEROIND_2004', 'EXPO_PAPEL_2004',
#        'EXPO_CAUCHO_2004', 'EXPO_QUIMICO_2004', 'EXPO_COMBIUST_2004',
#        'EXPO_HIERRO_2004', 'EXPO_METNOFERR_2004', 'EXPO_MAQUIN_2004',
#        'EXPO_RESTOIND_2004', 'PIB_perCap__variPorc',
#        'Vol_Cons_Hogares_per_Cap__vari_Porc', 'Vol_FBKF_perCap__variPorc',
#        'IPI__variPorc'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Anio', 'FBKF.Construcciones.Priv_Publ',
#        'FBKF.Equi_Dur_Prod.Mat_Transp.Nac',
#        'FBKF.Equi_Dur_Prod.Mat_Transp.Import',
#        'FBKF.Equi_Dur_Prod.Maqui_YEqui.Nac',
#        'FBKF.Equi_Dur_Prod.Maqui_YEqui.Import', 'Consumo.Hogares',
#        'Consumo.Gobierno', 'Exportaciones', 'Importaciones', 'GIB', 'FKBF',
#        'EXPO_TOT_2004', 'EXPO_AGROP_2004', 'EXPO_PAMP_2004',
#        'EXPO_PECUAR_2004', 'EXPO_CARNES_2004', 'EXPO_LECHE_2004',
#        'EXPO_LANAS_2004', 'EXPO_CUEROS_PP_2004', 'EXPO_AGRIC_2004',
#        'EXPO_CEREAL_2004', 'EXPO_OLEAGI_2004', 'EXPO_OTAGRIC_2004',
#        'EXPO_PESCA_2004', 'EXPO_INDUST_2004', 'EXPO_ALIMENT_2004',
#        'EXPO_TEXTIL_2004', 'EXPO_CUEROIND_2004', 'EXPO_PAPEL_2004',
#        'EXPO_CAUCHO_2004', 'EXPO_QUIMICO_2004', 'EXPO_COMBIUST_2004',
#        'EXPO_HIERRO_2004', 'EXPO_METNOFERR_2004', 'EXPO_MAQUIN_2004',
#        'EXPO_RESTOIND_2004', 'Consumo.Hogares.ipi.demanda',
# ...

# %%
filas_con_na = df[df.isna().any(axis=1)]
print(filas_con_na['Anio'].unique())  # o 'Year' según el nombre real
# Out:
# [1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961 1962 1963
#  1964 1965]

# %%
df[df.isna().any(axis=1)]
# Out:
#     Unnamed: 0  Anio  FBKF.Construcciones.Priv_Publ  \
# 0            1  1950                    20353627362
# 1            2  1951                    21739314091
# 2            3  1952                    19685428171
# 3            4  1953                    20237375978
# 4            5  1954                    19372130307
# 5            6  1955                    19934884939
# 6            7  1956                    20298654544
# 7            8  1957                    22249994812
# 8            9  1958                    25655101237
# 9           10  1959                    19600367624
# 10          11  1960                    23590349980
# 11          12  1961                    24664951203
# 12          13  1962                    22317304728
# 13          14  1963                    20905934123
# 14          15  1964                    22342653204
# 15          16  1965                    23138012760
#
# ...

# %%
df.fillna(0)
# Out:
#     Unnamed: 0  Anio  FBKF.Construcciones.Priv_Publ  \
# 0            1  1950                    20353627362
# 1            2  1951                    21739314091
# 2            3  1952                    19685428171
# 3            4  1953                    20237375978
# 4            5  1954                    19372130307
# ..         ...   ...                            ...
# 61          62  2011                    66813943052
# 62          63  2012                    64700327691
# 63          64  2013                    64634666531
# 64          65  2014                    63301703123
# 65          66  2015                    64462175043
#
#     FBKF.Equi_Dur_Prod.Mat_Transp.Nac  FBKF.Equi_Dur_Prod.Mat_Transp.Import  \
# 0                        6.685869e+08                          5.844002e+08
# 1                        8.427402e+08                          2.532758e+09
# 2                        1.119084e+09                          1.484422e+09
# ...

# %%
# Ejercicio 7
penguins_sin_na = penguins.dropna()
penguins_sin_na
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins_sin_na = penguins_sin_na.reset_index(drop=True)
penguins_sin_na
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen            36.7           19.3              193.0
# 4    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 328  Gentoo     Biscoe            47.2           13.7              214.0
# 329  Gentoo     Biscoe            46.8           14.3              215.0
# 330  Gentoo     Biscoe            50.4           15.7              222.0
# 331  Gentoo     Biscoe            45.2           14.8              212.0
# 332  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.dropna().reset_index(drop=True)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen            36.7           19.3              193.0
# 4    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 328  Gentoo     Biscoe            47.2           13.7              214.0
# 329  Gentoo     Biscoe            46.8           14.3              215.0
# 330  Gentoo     Biscoe            50.4           15.7              222.0
# 331  Gentoo     Biscoe            45.2           14.8              212.0
# 332  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# Ejercicio 8
# a)
[saludo + "!" for saludo in ["hola", "chau"]]
# Out:
# ['hola!', 'chau!']

# %%
# b)
[col.upper() for col in penguins.columns]
# Out:
# ['SPECIES',
#  'ISLAND',
#  'BILL_LENGTH_MM',
#  'BILL_DEPTH_MM',
#  'FLIPPER_LENGTH_MM',
#  'BODY_MASS_G',
#  'SEX']

# %%
[x * 10 if x % 2 == 0 else x for x in [1,2,3,4,5,6]]
# Out:
# [1, 20, 3, 40, 5, 60]

# %%
# Ejercicio 9
[col.upper() if col.startswith('bill') else col for col in penguins.columns]
# Out:
# ['species',
#  'island',
#  'BILL_LENGTH_MM',
#  'BILL_DEPTH_MM',
#  'flipper_length_mm',
#  'body_mass_g',
#  'sex']

# %%
# Ejercicio 10
penguins['peso_bin'] = penguins['body_mass_g'].apply(lambda x: 'chico' if x < 4000 else 'grande')

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex peso_bin
# 0         3750.0    Male    chico
# ...

# %%
# Ejercicio 11
# Filtrar filas
penguins_filtrado = penguins[(penguins['sex'] == 'Male') & (penguins['flipper_length_mm'] > 200)]

# Seleccionar columnas que terminan en '_mm'
columnas_mm = [col for col in penguins.columns if col.endswith('_mm')]

# Resultado final
resultado = penguins_filtrado[columnas_mm]
resultado
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm
# 91             41.1           18.1              205.0
# 95             40.8           18.9              208.0
# 101            41.0           20.0              203.0
# 123            41.4           18.5              202.0
# 129            44.1           18.0              210.0
# ..              ...            ...                ...
# 333            51.5           16.3              230.0
# 335            55.1           16.0              230.0
# 337            48.8           16.2              222.0
# 341            50.4           15.7              222.0
# 343            49.9           16.1              213.0
#
# [84 rows x 3 columns]

# %%
# Ejercicio 12
pinguinos_solo_de_Dream = penguins[penguins["island"] == "Dream"]
pinguinos_solo_de_Dream
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30      Adelie  Dream            39.5           16.7              178.0
# 31      Adelie  Dream            37.2           18.1              178.0
# 32      Adelie  Dream            39.5           17.8              188.0
# 33      Adelie  Dream            40.9           18.9              184.0
# 34      Adelie  Dream            36.4           17.0              195.0
# ..         ...    ...             ...            ...                ...
# 215  Chinstrap  Dream            55.8           19.8              207.0
# 216  Chinstrap  Dream            43.5           18.1              202.0
# 217  Chinstrap  Dream            49.6           18.2              193.0
# 218  Chinstrap  Dream            50.8           19.0              210.0
# 219  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex peso_bin
# 30        3250.0  Female    chico
# ...

# %%
[col for col in penguins.columns if col == "species" or col.startswith("bill")]
# Out:
# ['species', 'bill_length_mm', 'bill_depth_mm']

# %%
pinguinos_solo_de_Dream[[col for col in penguins.columns if col == "species" or col.startswith("bill")]]
# Out:
#        species  bill_length_mm  bill_depth_mm
# 30      Adelie            39.5           16.7
# 31      Adelie            37.2           18.1
# 32      Adelie            39.5           17.8
# 33      Adelie            40.9           18.9
# 34      Adelie            36.4           17.0
# ..         ...             ...            ...
# 215  Chinstrap            55.8           19.8
# 216  Chinstrap            43.5           18.1
# 217  Chinstrap            49.6           18.2
# 218  Chinstrap            50.8           19.0
# 219  Chinstrap            50.2           18.7
#
# [124 rows x 3 columns]

# %%
# Ejercicio 13
penguins["boddy_mass_kg"] = penguins["body_mass_g"] / 100

# %%
penguins["island"] = penguins["island"].str.lower()

# %%
# Ejercicio 14
medianas = penguins.groupby('species')['body_mass_g'].agg('median')
medianas
# Out:
# species
# Adelie       3700.0
# Chinstrap    3700.0
# Gentoo       5000.0
# Name: body_mass_g, dtype: float64

# %%
penguins['mediana_body_mass_g'] = penguins['species'].map(medianas)
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  torgersen            39.1           18.7              181.0
# 1    Adelie  torgersen            39.5           17.4              186.0
# 2    Adelie  torgersen            40.3           18.0              195.0
# 3    Adelie  torgersen             NaN            NaN                NaN
# 4    Adelie  torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     biscoe             NaN            NaN                NaN
# 340  Gentoo     biscoe            46.8           14.3              215.0
# 341  Gentoo     biscoe            50.4           15.7              222.0
# 342  Gentoo     biscoe            45.2           14.8              212.0
# 343  Gentoo     biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex peso_bin  boddy_mass_kg  mediana_body_mass_g
# ...

# %%
# Ejercicio 15
penguins_filtrado = penguins[penguins['island'] != 'Biscoe']

# %%
penguins_filtrado = penguins_filtrado.loc[:, "species":"body_mass_g"]
penguins_filtrado
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  torgersen            39.1           18.7              181.0
# 1    Adelie  torgersen            39.5           17.4              186.0
# 2    Adelie  torgersen            40.3           18.0              195.0
# 3    Adelie  torgersen             NaN            NaN                NaN
# 4    Adelie  torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     biscoe             NaN            NaN                NaN
# 340  Gentoo     biscoe            46.8           14.3              215.0
# 341  Gentoo     biscoe            50.4           15.7              222.0
# 342  Gentoo     biscoe            45.2           14.8              212.0
# 343  Gentoo     biscoe            49.9           16.1              213.0
#
#      body_mass_g
# 0         3750.0
# 1         3800.0
# 2         3250.0
# 3            NaN
# ...

# %%
penguins_filtrado = penguins_filtrado.rename(columns = {"species":"especie_pinguino"})
penguins_filtrado
# Out:
#     especie_pinguino     island  bill_length_mm  bill_depth_mm  \
# 0             Adelie  torgersen            39.1           18.7
# 1             Adelie  torgersen            39.5           17.4
# 2             Adelie  torgersen            40.3           18.0
# 3             Adelie  torgersen             NaN            NaN
# 4             Adelie  torgersen            36.7           19.3
# ..               ...        ...             ...            ...
# 339           Gentoo     biscoe             NaN            NaN
# 340           Gentoo     biscoe            46.8           14.3
# 341           Gentoo     biscoe            50.4           15.7
# 342           Gentoo     biscoe            45.2           14.8
# 343           Gentoo     biscoe            49.9           16.1
#
#      flipper_length_mm  body_mass_g
# 0                181.0       3750.0
# 1                186.0       3800.0
# 2                195.0       3250.0
# 3                  NaN          NaN
# ...

# %%
penguins_agrupados = penguins_filtrado.groupby("especie_pinguino")
penguins_agrupados

# %%
columnas_length = [col for col in penguins_filtrado.columns if "length" in col]
columnas_length
# Out:
# ['bill_length_mm', 'flipper_length_mm']

# %%
resultado = penguins_agrupados[columnas_length].agg("mean")
resultado
# Out:
#                   bill_length_mm  flipper_length_mm
# especie_pinguino
# Adelie                 38.791391         189.953642
# Chinstrap              48.833824         195.823529
# Gentoo                 47.504878         217.186992

# %%
resultado = resultado.rename(columns = {col : col + "_mean" for col in columnas_length})
resultado
# Out:
#                   bill_length_mm_mean  flipper_length_mm_mean
# especie_pinguino
# Adelie                      38.791391              189.953642
# Chinstrap                   48.833824              195.823529
# Gentoo                      47.504878              217.186992

# %%
# Ejercicio 16
macroFull = pd.read_csv(r"C:\Users\Usuario\Downloads\macro_full_columns.csv", index_col = "Anio")
macroFull
# Out:
#       Unnamed: 0  FBKF.Construcciones.Priv_Publ  \
# Anio
# 1950           1                    20353627362
# 1951           2                    21739314091
# 1952           3                    19685428171
# 1953           4                    20237375978
# 1954           5                    19372130307
# ...          ...                            ...
# 2011          62                    66813943052
# 2012          63                    64700327691
# 2013          64                    64634666531
# 2014          65                    63301703123
# 2015          66                    64462175043
#
#       FBKF.Equi_Dur_Prod.Mat_Transp.Nac  FBKF.Equi_Dur_Prod.Mat_Transp.Import  \
# Anio
# 1950                       6.685869e+08                          5.844002e+08
# 1951                       8.427402e+08                          2.532758e+09
# 1952                       1.119084e+09                          1.484422e+09
# ...

# %%
macroFull.columns
# Out:
# Index(['Unnamed: 0', 'FBKF.Construcciones.Priv_Publ',
#        'FBKF.Equi_Dur_Prod.Mat_Transp.Nac',
#        'FBKF.Equi_Dur_Prod.Mat_Transp.Import',
#        'FBKF.Equi_Dur_Prod.Maqui_YEqui.Nac',
#        'FBKF.Equi_Dur_Prod.Maqui_YEqui.Import', 'Consumo.Hogares',
#        'Consumo.Gobierno', 'Exportaciones', 'Importaciones', 'GIB', 'FKBF',
#        'EXPO_TOT_2004', 'EXPO_AGROP_2004', 'EXPO_PAMP_2004',
#        'EXPO_PECUAR_2004', 'EXPO_CARNES_2004', 'EXPO_LECHE_2004',
#        'EXPO_LANAS_2004', 'EXPO_CUEROS_PP_2004', 'EXPO_AGRIC_2004',
#        'EXPO_CEREAL_2004', 'EXPO_OLEAGI_2004', 'EXPO_OTAGRIC_2004',
#        'EXPO_PESCA_2004', 'EXPO_INDUST_2004', 'EXPO_ALIMENT_2004',
#        'EXPO_TEXTIL_2004', 'EXPO_CUEROIND_2004', 'EXPO_PAPEL_2004',
#        'EXPO_CAUCHO_2004', 'EXPO_QUIMICO_2004', 'EXPO_COMBIUST_2004',
#        'EXPO_HIERRO_2004', 'EXPO_METNOFERR_2004', 'EXPO_MAQUIN_2004',
#        'EXPO_RESTOIND_2004', 'Consumo.Hogares.ipi.demanda',
# ...

# %%
macroFull = macroFull.drop(columns = ["Unnamed: 0"])
macroFull
# Out:
#       FBKF.Construcciones.Priv_Publ  FBKF.Equi_Dur_Prod.Mat_Transp.Nac  \
# Anio
# 1950                    20353627362                       6.685869e+08
# 1951                    21739314091                       8.427402e+08
# 1952                    19685428171                       1.119084e+09
# 1953                    20237375978                       1.207891e+09
# 1954                    19372130307                       1.173452e+09
# ...                             ...                                ...
# 2011                    66813943052                       1.189902e+10
# 2012                    64700327691                       1.193748e+10
# 2013                    64634666531                       1.378317e+10
# 2014                    63301703123                       1.030574e+10
# 2015                    64462175043                       1.143976e+10
#
#       FBKF.Equi_Dur_Prod.Mat_Transp.Import  \
# Anio
# 1950                          5.844002e+08
# ...

# %%
[col.replace("vari_Porc", "variPorc") for col in macroFull.columns]
# Out:
# ['FBKF.Construcciones.Priv_Publ',
#  'FBKF.Equi_Dur_Prod.Mat_Transp.Nac',
#  'FBKF.Equi_Dur_Prod.Mat_Transp.Import',
#  'FBKF.Equi_Dur_Prod.Maqui_YEqui.Nac',
#  'FBKF.Equi_Dur_Prod.Maqui_YEqui.Import',
#  'Consumo.Hogares',
#  'Consumo.Gobierno',
#  'Exportaciones',
#  'Importaciones',
#  'GIB',
#  'FKBF',
#  'EXPO_TOT_2004',
#  'EXPO_AGROP_2004',
#  'EXPO_PAMP_2004',
#  'EXPO_PECUAR_2004',
#  'EXPO_CARNES_2004',
#  'EXPO_LECHE_2004',
#  'EXPO_LANAS_2004',
#  'EXPO_CUEROS_PP_2004',
#  'EXPO_AGRIC_2004',
#  'EXPO_CEREAL_2004',
#  'EXPO_OLEAGI_2004',
#  'EXPO_OTAGRIC_2004',
#  'EXPO_PESCA_2004',
#  'EXPO_INDUST_2004',
#  'EXPO_ALIMENT_2004',
#  'EXPO_TEXTIL_2004',
#  'EXPO_CUEROIND_2004',
#  'EXPO_PAPEL_2004',
#  'EXPO_CAUCHO_2004',
#  'EXPO_QUIMICO_2004',
#  'EXPO_COMBIUST_2004',
#  'EXPO_HIERRO_2004',
#  'EXPO_METNOFERR_2004',
#  'EXPO_MAQUIN_2004',
#  'EXPO_RESTOIND_2004',
#  'Consumo.Hogares.ipi.demanda',
#  'Consumo.Gobierno.ipi.demanda',
# ...

# %%
[col.replace("_Per_Cap", "_perCap") for col in macroFull.columns]
# Out:
# ['FBKF.Construcciones.Priv_Publ',
#  'FBKF.Equi_Dur_Prod.Mat_Transp.Nac',
#  'FBKF.Equi_Dur_Prod.Mat_Transp.Import',
#  'FBKF.Equi_Dur_Prod.Maqui_YEqui.Nac',
#  'FBKF.Equi_Dur_Prod.Maqui_YEqui.Import',
#  'Consumo.Hogares',
#  'Consumo.Gobierno',
#  'Exportaciones',
#  'Importaciones',
#  'GIB',
#  'FKBF',
#  'EXPO_TOT_2004',
#  'EXPO_AGROP_2004',
#  'EXPO_PAMP_2004',
#  'EXPO_PECUAR_2004',
#  'EXPO_CARNES_2004',
#  'EXPO_LECHE_2004',
#  'EXPO_LANAS_2004',
#  'EXPO_CUEROS_PP_2004',
#  'EXPO_AGRIC_2004',
#  'EXPO_CEREAL_2004',
#  'EXPO_OLEAGI_2004',
#  'EXPO_OTAGRIC_2004',
#  'EXPO_PESCA_2004',
#  'EXPO_INDUST_2004',
#  'EXPO_ALIMENT_2004',
#  'EXPO_TEXTIL_2004',
#  'EXPO_CUEROIND_2004',
#  'EXPO_PAPEL_2004',
#  'EXPO_CAUCHO_2004',
#  'EXPO_QUIMICO_2004',
#  'EXPO_COMBIUST_2004',
#  'EXPO_HIERRO_2004',
#  'EXPO_METNOFERR_2004',
#  'EXPO_MAQUIN_2004',
#  'EXPO_RESTOIND_2004',
#  'Consumo.Hogares.ipi.demanda',
#  'Consumo.Gobierno.ipi.demanda',
# ...
