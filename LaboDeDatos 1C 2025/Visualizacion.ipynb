# %%
from gapminder import gapminder
import seaborn.objects as so

# %%
datosArgentina = gapminder[gapminder["country"] == "Argentina"]
datosArgentina
# Out:
#       country continent  year  lifeExp       pop     gdpPercap
# 48  Argentina  Americas  1952   62.485  17876956   5911.315053
# 49  Argentina  Americas  1957   64.399  19610538   6856.856212
# 50  Argentina  Americas  1962   65.142  21283783   7133.166023
# 51  Argentina  Americas  1967   65.634  22934225   8052.953021
# 52  Argentina  Americas  1972   67.065  24779799   9443.038526
# 53  Argentina  Americas  1977   68.481  26983828  10079.026740
# 54  Argentina  Americas  1982   69.942  29341374   8997.897412
# 55  Argentina  Americas  1987   70.774  31620918   9139.671389
# 56  Argentina  Americas  1992   71.868  33958947   9308.418710
# 57  Argentina  Americas  1997   73.275  36203463  10967.281950
# 58  Argentina  Americas  2002   74.340  38331121   8797.640716
# 59  Argentina  Americas  2007   75.320  40301927  12779.379640

# %%
(
    so.Plot(data = datosArgentina, x="year", y="lifeExp")
    .add(so.Line())
)

# %%
datosAmerica = gapminder[gapminder["continent"] == "Americas"]
datosAmerica
# Out:
#         country continent  year  lifeExp       pop     gdpPercap
# 48    Argentina  Americas  1952   62.485  17876956   5911.315053
# 49    Argentina  Americas  1957   64.399  19610538   6856.856212
# 50    Argentina  Americas  1962   65.142  21283783   7133.166023
# 51    Argentina  Americas  1967   65.634  22934225   8052.953021
# 52    Argentina  Americas  1972   67.065  24779799   9443.038526
# ...         ...       ...   ...      ...       ...           ...
# 1639  Venezuela  Americas  1987   70.190  17910182   9883.584648
# 1640  Venezuela  Americas  1992   71.150  20265563  10733.926310
# 1641  Venezuela  Americas  1997   72.146  22374398  10165.495180
# 1642  Venezuela  Americas  2002   72.766  24287670   8605.047831
# 1643  Venezuela  Americas  2007   73.747  26084662  11415.805690
#
# [300 rows x 6 columns]

# %%
(
    so.Plot(data = datosAmerica, x="year", y="lifeExp", color="country")
    .add(so.Line())
)

# %%
#Codigo1
(
    so.Plot(data = datosAmerica, x="year", y="lifeExp", group="country")
    .add(so.Line(color="#bbca"))
    .add(so.Line(), so.PolyFit(1))
)

# %%
#Codigo 2
(
    so.Plot(data = datosAmerica, x="year", y="lifeExp")
    .add(so.Line(color="#bbca"), group="country")
    .add(so.Line(), so.PolyFit(1))
)

# %%
(
    so.Plot(data = gapminder, x="year", y="lifeExp")
    .add(so.Line(color="#bbca"), group="country")
    .add(so.Line(), so.PolyFit(1))
    .facet("continent", wrap=3)
)

# %%
#Ejercicio 2
import seaborn as sns
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
#Ejercicio3
(
    so.Plot(
        penguins, x="bill_length_mm", y="bill_depth_mm",
        edgewidth="body_mass_g", marker="species",
        linestyle="island", color="species"
    )
    .add(so.Dot(color=".8"), edgecolor="sex")
)

# %%
#Ejercicio 4
(
    so.Plot(penguins, x="bill_depth_mm", y="bill_length_mm")
    .add(so.Dot())
)

# %%
(
    so.Plot(penguins, x="bill_depth_mm", y="bill_length_mm", color="species")
    .add(so.Dot())
)

# %%
#Ejercicio 5
(
    so.Plot(penguins, x="bill_depth_mm", y="bill_length_mm", color="sex")
    .add(so.Dot())
)

# %%
(
    so.Plot(penguins, x="bill_depth_mm", y="bill_length_mm", color="sex")
    .add(so.Dot())
    .facet("species", wrap=2)
)

# %%
#Ejercicio 6
pinguinos_por_isla = penguins.groupby("island").size()
pinguinos_por_isla
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# dtype: int64

# %%
(
    so.Plot(x=pinguinos_por_isla.index, y=pinguinos_por_isla.values)
    .add(so.Bar())
)

# %%
(
    so.Plot(data = penguins, x="island")
    .add(so.Bar(), so.Hist())
)

# %%
(
    so.Plot(data = penguins, x="island")
    .add(so.Bar(), so.Hist(), so.Dodge(), color="species")
)

# %%
(
    so.Plot(data = penguins, x="island")
    .add(so.Bar(), so.Hist())
    .facet("species")
)

# %%
# Ejercicio 7
(
    so.Plot(data = penguins, x="flipper_length_mm")
    .add(so.Bar(), so.Hist())
)

# %%
print(penguins["flipper_length_mm"].min())
print(penguins["flipper_length_mm"].max())
print(penguins["flipper_length_mm"].mean())
print(penguins["flipper_length_mm"].median())
# Out:
# 172.0
# 231.0
# 200.91520467836258
# 197.0

# %%
# Ejercicio 8
print(penguins["bill_depth_mm"].describe())
# Out:
# count    342.000000
# mean      17.151170
# std        1.974793
# min       13.100000
# 25%       15.600000
# 50%       17.300000
# 75%       18.700000
# max       21.500000
# Name: bill_depth_mm, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data = penguins, x="species", y="bill_depth_mm")
plt.show()

# %%
# Ejercicio 9
(
    so.Plot(data = penguins, x="bill_depth_mm", y="bill_length_mm", pointsize="body_mass_g")
    .add(so.Dot())
)

# %%
sns.boxplot(data = penguins, x="species", y="body_mass_g")
plt.show()

# %%
# Ejercicio 10
# Haria de barras

# %%
# Ejercicio 11
# Para las variables numericas, como peso, altura y edad haria un boxplot y para las variables categoricas como sexo
# haria un grafico de barras
# Para ver la relacion entre peso y latura usaria un scatterplot para ver la relacion entre ellas

# %%
# Ejericio 12
paises_unicos = gapminder.drop_duplicates(subset = ["country", "continent"])
paises_por_continente = paises_unicos.groupby("continent").size()

# %%
(
    so.Plot(x=paises_por_continente.index, y=paises_por_continente.values)
    .add(so.Bar())
)

# %%
# Con histogramas
datos_unicos = gapminder.drop_duplicates(subset="country")

(
    so.Plot(data = datos_unicos, x="continent")
    .add(so.Bar(), so.Hist())
)

# %%
# Ejercicio 13

sns.boxplot(gapminder, x="continent", y="lifeExp", 
            order=sorted(gapminder["continent"].unique()))
# Out:
# <Axes: xlabel='continent', ylabel='lifeExp'>
